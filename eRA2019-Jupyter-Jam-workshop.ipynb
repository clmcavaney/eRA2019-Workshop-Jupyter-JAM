# %% [markdown]
# # Testing SWAN within Cloudstor

# %% [markdown]
# load the Pandas library

# %%
import pandas as pd

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read in the Solar data

# %%
df = pd.read_excel('cloudstor/Shared/Alex-Solar.xlsx')

# %%
# debugging
df.head()
# Out:
#   Unnamed: 0  days  bought  produced  consumed  sold
# 0 2016-01-06     0     314       637       471   480
# 1 2016-03-05    59     327       664       556   435
# 2 2016-05-04   119     297       495       398   394
# 3 2016-07-06   182     147       438       216   369
# 4 2016-09-05   243     379       453       532   300

# %%
# plot the data
my_plot = df.plot(kind='line', x=0, y={'bought', 'consumed', 'sold'})
my_plot.set_xlabel('date')
my_plot.set_ylabel('kWh')
# Out:
# Text(0, 0.5, 'kWh')
